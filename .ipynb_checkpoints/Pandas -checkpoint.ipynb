# %% [markdown]
# ## PANDAS IN PYTHON

# %% [markdown]
# ### SERIES

# %%
import numpy as np

# %%
import pandas as pd

# %%
my_data = [10,20,30]
labels = ['a','b','c']
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(data = my_data,index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1=pd.Series([1,2,3,4],['USA','INDIA','JAPAN','FRANCE'])
ser2=pd.Series([1,2,5,7],['USA','ITLY','JAPAN','FRANCE'])

# %%
ser1
# Out:
# USA       1
# INDIA     2
# JAPAN     3
# FRANCE    4
# dtype: int64

# %%
ser2
# Out:
# USA       1
# ITLY      2
# JAPAN     5
# FRANCE    7
# dtype: int64

# %%
ser1['JAPAN']
# Out:
# 3

# %%
ser1+ser2
# Out:
# FRANCE    11.0
# INDIA      NaN
# ITLY       NaN
# JAPAN      8.0
# USA        2.0
# dtype: float64

# %% [markdown]
# ## DATAFRAME

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(6,5),['A','B','C','D','E','F',],['V','W','X','Y','Z'])

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df['X']
# Out:
# A    0.907969
# B    0.605965
# C    0.188695
# D    1.978757
# E   -1.706086
# F    0.184502
# Name: X, dtype: float64

# %%
type(df['X'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  0.628133  0.651118
# B -0.848077  0.740122
# C -0.589001 -0.933237
# D  0.190794  0.683509
# E  1.693723 -0.134841
# F  0.166905  0.072960

# %%
df['new']=df['V'] + df['Y']     # to add column !

# %%
df
# Out:
#           V         W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.210676
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -2.337486
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.230059
# D  0.955057  0.190794  1.978757  2.605967  0.683509  3.561024
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841 -0.856454
# F  0.390528  0.166905  0.184502  0.807706  0.072960  1.198234

# %%
df.drop('new',axis=1)     #temporary remove of column !
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df
# Out:
#           V         W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  0.651118  3.210676
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122 -2.337486
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237 -0.230059
# D  0.955057  0.190794  1.978757  2.605967  0.683509  3.561024
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841 -0.856454
# F  0.390528  0.166905  0.184502  0.807706  0.072960  1.198234

# %%
df.drop('new',axis=1,inplace=True)     # Permenant remove of column !

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df.drop('C',axis=0)
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df.loc['A']    #Grabbing rows by name !
# Out:
# V    2.706850
# W    0.628133
# X    0.907969
# Y    0.503826
# Z    0.651118
# Name: A, dtype: float64

# %%
df.iloc[2]      #Grabbing rows by index number !
# Out:
# V    0.528813
# W   -0.589001
# X    0.188695
# Y   -0.758872
# Z   -0.933237
# Name: C, dtype: float64

# %%
df.loc['E','X']      # Grabbing perticular element!
# Out:
# -1.7060859307350775

# %%
df.loc[['A','C','E'],['W','Y']]
# Out:
#           W         Y
# A  0.628133  0.503826
# C -0.589001 -0.758872
# E  1.693723 -1.159119

# %%
## conditional selections !

# %%
df >0
# Out:
#        V      W      X      Y      Z
# A   True   True   True   True   True
# B  False  False   True  False   True
# C   True  False   True  False  False
# D   True   True   True   True   True
# E   True   True  False  False  False
# F   True   True   True   True   True

# %%
df_bool = df>0

# %%
df[df_bool]
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B       NaN       NaN  0.605965       NaN  0.740122
# C  0.528813       NaN  0.188695       NaN       NaN
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723       NaN       NaN       NaN
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df['W']>0
# Out:
# A     True
# B    False
# C    False
# D     True
# E     True
# F     True
# Name: W, dtype: bool

# %%
df['W']
# Out:
# A    0.628133
# B   -0.848077
# C   -0.589001
# D    0.190794
# E    1.693723
# F    0.166905
# Name: W, dtype: float64

# %%
df[df['W']>0]
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df[df['V']<0]
# Out:
#           V         W         X         Y         Z
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122

# %%
result = df[df['W']>0]

# %%
result
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
result['X']
# Out:
# A    0.907969
# D    1.978757
# E   -1.706086
# F    0.184502
# Name: X, dtype: float64

# %%
df[df['W']>0]['X']    # in one line !
# Out:
# A    0.907969
# D    1.978757
# E   -1.706086
# F    0.184502
# Name: X, dtype: float64

# %%
df[df['W']>0][['X','Y']]
# Out:
#           X         Y
# A  0.907969  0.503826
# D  1.978757  2.605967
# E -1.706086 -1.159119
# F  0.184502  0.807706

# %%
bool_ser = df['W']>0
result = df[bool_ser]
my_col = ['X','Y']
final = result[my_col]

# %%
final
# Out:
#           X         Y
# A  0.907969  0.503826
# D  1.978757  2.605967
# E -1.706086 -1.159119
# F  0.184502  0.807706

# %%
df[(df['W']>0) & (df['X']<0)]
# Out:
#           V         W         X         Y         Z
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
df[(df['W']<0) | (df['X']<0)]
# Out:
#           V         W         X         Y         Z
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841

# %%
df.reset_index()
# Out:
#   index         V         W         X         Y         Z
# 0     A  2.706850  0.628133  0.907969  0.503826  0.651118
# 1     B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# 2     C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# 3     D  0.955057  0.190794  1.978757  2.605967  0.683509
# 4     E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 5     F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df
# Out:
#           V         W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826  0.651118
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237
# D  0.955057  0.190794  1.978757  2.605967  0.683509
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# F  0.390528  0.166905  0.184502  0.807706  0.072960

# %%
new_ind = "OA BC KC MF RO NJ".split()

# %%
new_ind
# Out:
# ['OA', 'BC', 'KC', 'MF', 'RO', 'NJ']

# %%
df['States'] = new_ind

# %%
df
# Out:
#           V         W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826  0.651118     OA
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122     BC
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237     KC
# D  0.955057  0.190794  1.978757  2.605967  0.683509     MF
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841     RO
# F  0.390528  0.166905  0.184502  0.807706  0.072960     NJ

# %%
df.set_index('States')
# Out:
#                V         W         X         Y         Z
# States
# OA      2.706850  0.628133  0.907969  0.503826  0.651118
# BC     -0.319318 -0.848077  0.605965 -2.018168  0.740122
# KC      0.528813 -0.589001  0.188695 -0.758872 -0.933237
# MF      0.955057  0.190794  1.978757  2.605967  0.683509
# RO      0.302665  1.693723 -1.706086 -1.159119 -0.134841
# NJ      0.390528  0.166905  0.184502  0.807706  0.072960

# %%
df
# Out:
#           V         W         X         Y         Z States
# A  2.706850  0.628133  0.907969  0.503826  0.651118     OA
# B -0.319318 -0.848077  0.605965 -2.018168  0.740122     BC
# C  0.528813 -0.589001  0.188695 -0.758872 -0.933237     KC
# D  0.955057  0.190794  1.978757  2.605967  0.683509     MF
# E  0.302665  1.693723 -1.706086 -1.159119 -0.134841     RO
# F  0.390528  0.166905  0.184502  0.807706  0.072960     NJ

# %% [markdown]
# ## Multi-Index and Index Hierarchy¶

# %% [markdown]
# .

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
list(zip(outside,inside))
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1 -1.136645  0.000366
#    2  1.025984 -0.156598
#    3 -0.031579  0.649826
# G2 1  2.154846 -0.610259
#    2 -0.755325 -0.346419
#    3  0.147027 -0.479448

# %%
df.loc['G1'].loc[1]
# Out:
# A   -1.136645
# B    0.000366
# Name: 1, dtype: float64

# %%
df.loc['G1'].iloc[0]
# Out:
# A   -1.136645
# B    0.000366
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ["Group","Num"]

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1   -1.136645  0.000366
#       2    1.025984 -0.156598
#       3   -0.031579  0.649826
# G2    1    2.154846 -0.610259
#       2   -0.755325 -0.346419
#       3    0.147027 -0.479448

# %%
# Lets grab G2--> 2 ---> B

df.loc['G2'].loc[2]['B']
# Out:
# -0.34641850351854453

# %%
df.xs(1,level = 'Num')
# Out:
#               A         B
# Group
# G1    -1.136645  0.000366
# G2     2.154846 -0.610259
